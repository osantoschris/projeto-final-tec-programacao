# %%
import pandas as pd

df = pd.read_csv('WorldCups.csv', sep=",")
df

# %%
df.shape
# Out:
# (20, 10)

# %%
df.describe()
# Out:
#               Year  GoalsScored  QualifiedTeams  MatchesPlayed
# count    20.000000    20.000000       20.000000      20.000000
# mean   1974.800000   118.950000       21.250000      41.800000
# std      25.582889    32.972836        7.268352      17.218717
# min    1930.000000    70.000000       13.000000      17.000000
# 25%    1957.000000    89.000000       16.000000      30.500000
# 50%    1976.000000   120.500000       16.000000      38.000000
# 75%    1995.000000   145.250000       26.000000      55.000000
# max    2014.000000   171.000000       32.000000      64.000000

# %%
df.head(2)
# Out:
#    Year  Country   Winner      Runners-Up    Third      Fourth  GoalsScored  \
# 0  1930  Uruguay  Uruguay       Argentina      USA  Yugoslavia           70
# 1  1934    Italy    Italy  Czechoslovakia  Germany     Austria           70
#
#    QualifiedTeams  MatchesPlayed Attendance
# 0              13             18    590.549
# 1              16             17    363.000

# %%
df = df.rename(columns={'Year':'Ano','Country':'País','Winner':'Campeão','Runners-Up': 'Vice-Campeão','Third':'Terceiro','Fourth':'Quarto', 'GoalsScored':"Gols Marcados", 'QualifiedTeams':'Equipes Qualificads', 'MatchesPlayed':'Partidas Jogadas','Attendance':'Publico' })
df.head()
# Out:
#     Ano         País     Campeão    Vice-Campeão Terceiro      Quarto  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    Gols Marcados  Equipes Qualificads  Partidas Jogadas    Publico
# 0             70                   13                18    590.549
# 1             70                   16                17    363.000
# 2             84                   15                18    375.700
# 3             88                   13                22  1.045.246
# 4            140                   16                26    768.607

# %%
df.loc[0:5, ['Ano', 'País','Campeão', 'Publico']]
# Out:
#     Ano         País     Campeão    Publico
# 0  1930      Uruguay     Uruguay    590.549
# 1  1934        Italy       Italy    363.000
# 2  1938       France       Italy    375.700
# 3  1950       Brazil     Uruguay  1.045.246
# 4  1954  Switzerland  Germany FR    768.607
# 5  1958       Sweden      Brazil    819.810

# %%
# QUANTIDADE DE VEZES QUE UM PAÍS FOI CAMPEÃO
df.value_counts(['Campeão'])
# Out:
# Campeão
# Brazil        5
# Italy         4
# Germany FR    3
# Argentina     2
# Uruguay       2
# England       1
# France        1
# Germany       1
# Spain         1
# dtype: int64

# %%
# Quais copas o brasil foi campeão
df.loc[df['Campeão']=='Brazil']
# Out:
#      Ano         País Campeão    Vice-Campeão    Terceiro          Quarto  \
# 5   1958       Sweden  Brazil          Sweden      France      Germany FR
# 6   1962        Chile  Brazil  Czechoslovakia       Chile      Yugoslavia
# 8   1970       Mexico  Brazil           Italy  Germany FR         Uruguay
# 14  1994          USA  Brazil           Italy      Sweden        Bulgaria
# 16  2002  Korea/Japan  Brazil         Germany      Turkey  Korea Republic
#
#     Gols Marcados  Equipes Qualificads  Partidas Jogadas    Publico
# 5             126                   16                35    819.810
# 6              89                   16                32    893.172
# 8              95                   16                32  1.603.975
# 14            141                   24                52  3.587.538
# 16            161                   32                64  2.705.197

# %%
# QUANTAS VEZES O BRASIL FOI VICE-CAMPEÃO
df.value_counts(['Vice-Campeão'])['Brazil']
# Out:
# 2

# %%
# Quais os anos o Brasil foi Vice-Campeão
df.loc[df['Vice-Campeão']=='Brazil']
# Out:
#      Ano    País  Campeão Vice-Campeão Terceiro       Quarto  Gols Marcados  \
# 3   1950  Brazil  Uruguay       Brazil   Sweden        Spain             88
# 15  1998  France   France       Brazil  Croatia  Netherlands            171
#
#     Equipes Qualificads  Partidas Jogadas    Publico
# 3                    13                22  1.045.246
# 15                   32                64  2.785.100

# %%
import pandas as pd

df1 = pd.read_csv('worldCupPlayers.csv', sep=',')
df1.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
df1 = df1.rename(columns={'RoundID':'Id Rodada', 'MatchID':'Id Corresp', 'Team Initials':'Inciais Equipe','Coach Name':'Treinador', 'Line-up':'Alinhar', 'Shirt Number':'Número Camisa','Player Name':'Nome Jogador', 'Position':'Posição','Event':'Evento'})
df1.head(2)
# Out:
#    Id Rodada  Id Corresp Inciais Equipe            Treinador Alinhar  \
# 0        201        1096            FRA  CAUDRON Raoul (FRA)       S
# 1        201        1096            MEX     LUQUE Juan (MEX)       S
#
#    Número Camisa     Nome Jogador Posição Evento
# 0              0      Alex THEPOT      GK    NaN
# 1              0  Oscar BONFIGLIO      GK    NaN

# %%
import pandas as pd
df2 = pd.read_csv('WorldCupMatches.csv')
df2.head(3)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
#
#                   Referee               Assistant 1            Assistant 2  \
# ...

# %%
df2 = df2.rename(columns={'Year':'Ano', 'Datetime':'Data Hora', 'Stage':'Grupo','Stadium':'Estádio', 'City':'Cidade', 'Home Team Name':'Equipe da Casa','Home Team Goals':'Gols Equipe Casa', 'Away Team Goals':'GolsVisitante','Away Team Name':'Equipe Visitante','Attendance':'Publico','Referee':'Juiz'})
df2.head(2)
# Out:
#       Ano             Data Hora    Grupo         Estádio       Cidade  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
#
#   Equipe da Casa  Gols Equipe Casa  GolsVisitante Equipe Visitante  \
# 0         France               4.0            1.0           Mexico
# 1            USA               3.0            0.0          Belgium
#
#   Win conditions  Publico  Half-time Home Goals  Half-time Away Goals  \
# 0                  4444.0                   3.0                   0.0
# 1                 18346.0                   2.0                   0.0
#
#                      Juiz               Assistant 1            Assistant 2  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)    REGO Gilberto (BRA)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)  WARNKEN Alberto (CHI)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# ...

# %%
# Maior publico em cada grupo de todas as copas.
df2.groupby(['Grupo']).apply(lambda df2: df2.loc[df2.Publico.idxmax()])
# Out:
#                              Ano             Data Hora  \
# Grupo
# Final                     1986.0  29 Jun 1986 - 12:00
# First round               1938.0  05 Jun 1938 - 17:00
# Group 1                   1950.0  01 Jul 1950 - 15:00
# Group 2                   1982.0  02 Jul 1982 - 21:00
# Group 3                   1982.0  13 Jun 1982 - 20:00
# Group 4                   1974.0  19 Jun 1974 - 19:30
# Group 5                   1982.0  16 Jun 1982 - 21:00
# Group 6                   1950.0  16 Jul 1950 - 15:00
# Group A                   1986.0  31 May 1986 - 12:00
# Group B                   1986.0  07 Jun 1986 - 12:00
# Group C                   1998.0  18 Jun 1998 - 21:00
# Group D                   2010.0  23 Jun 2010 - 20:30
# Group E                   2010.0  14 Jun 2010 - 13:30
# Group F                   1994.0  25 Jun 1994 - 12:30
# Group G                   2010.0  20 Jun 2010 - 20:30
# Group H                   2014.0  22 Jun 2014 - 13:00
# ...

# %%
# Média de publico por estádio
df2[['Publico','Estádio']].groupby(['Estádio']).mean()
# Out:
#                        Publico
# Estádio
# Arena Amazonia    40056.750000
# Arena Fonte Nova  50385.000000
# Arena Pantanal    39679.250000
# Arena Pernambuco  41020.666667
# Arena da Baixada  39247.750000
# ...                        ...
# Wankdorf Stadium  38900.000000
# Wembley Stadium   86448.222222
# Westfalenstadion  46925.000000
# White City        45662.000000
# Zentralstadion    42000.000000
#
# [181 rows x 1 columns]

# %%
df2[['Publico', 'Estádio']].groupby('Estádio').mean()
# Out:
#                        Publico
# Estádio
# Arena Amazonia    40056.750000
# Arena Fonte Nova  50385.000000
# Arena Pantanal    39679.250000
# Arena Pernambuco  41020.666667
# Arena da Baixada  39247.750000
# ...                        ...
# Wankdorf Stadium  38900.000000
# Wembley Stadium   86448.222222
# Westfalenstadion  46925.000000
# White City        45662.000000
# Zentralstadion    42000.000000
#
# [181 rows x 1 columns]
